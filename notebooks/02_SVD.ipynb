# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# %%
import pickle

def get_and_save_or_load_maps(d):
  mm = "./processed/movie_to_index.pkl"
  uu = "./processed/user_to_index.pkl"
  try:
    with open(mm, 'rb') as f: d["movie_to_index"] = pickle.load(f)
    with open(uu, 'rb') as f: d["user_to_index"] = pickle.load(f)
  except:
    print("COULD NOT LOAD MAPS")
    d["movie_to_index"] = {m: i for i, m in enumerate(d["all_movies"])}
    d["user_to_index"] = {u: i for i, u in enumerate(d["all_users"])}
    with open(mm, 'wb') as f: pickle.dump(d["movie_to_index"], f)
    with open(uu, 'wb') as f: pickle.dump(d["user_to_index"], f)
  return d

# %%
def get_and_save_or_load_movies(d):
  mm = "./processed/all_movies.pkl"
  try:
    with open(mm, 'rb') as f: d["all_movies"] = pickle.load(f)
  except:
    print("COULD NOT LOAD MOVIES")
    d["all_movies"] = ratings_data.movie_id.unique()
    with open(mm, 'wb') as f: pickle.dump(d["all_movies"], f)
  return d

# %%
from sklearn.model_selection import train_test_split

def get_and_save_or_load_users(d, train_ratio, test_ratio):
  uu = "./processed/all_users.pkl"
  tt1 = "./processed/train_users.pkl"
  tt2 = "./processed/test_users.pkl"
  try:
    with open(uu, 'rb') as f: d["all_users"] = pickle.load(f)
    with open(tt1, 'rb') as f: d["train_users"] = pickle.load(f)
    with open(tt2, 'rb') as f: d["test_users"] = pickle.load(f)
  except:
    print("COULD NOT LOAD USERS")
    d["all_users"] = ratings_data.user_id.unique()
    d["train_users"], d["test_users"] = train_test_split(d["all_users"], train_size=train_ratio, test_size=test_ratio)
    with open(uu, 'wb') as f: pickle.dump(d["all_users"], f)
    with open(tt1, 'wb') as f: pickle.dump(d["train_users"], f)
    with open(tt2, 'wb') as f: pickle.dump(d["test_users"], f)
  return d

# %%
from scipy.sparse import coo_matrix

def get_and_save_or_load_matrix(d, test_or_train):
  s = test_or_train + "_matrix"
  tt = "./processed/" + s + ".pkl"
  try:
    with open(tt, 'rb') as f: d[s] = pickle.load(f)
  except:
    print("COULD NOT LOAD MATRIX: " + test_or_train)
    shape = (len(d["all_users"]), len(d["all_movies"]))
    df = ratings_data[ratings_data["user_id"].isin(d[test_or_train + "_users"])]
    row = df['user_id'].map(d['user_to_index']).values
    col = df['movie_id'].map(d['movie_to_index']).values
    data = df['rating_val'].values
    d[s] = coo_matrix((data, (row, col)), shape=shape)
    d[s] = d[s].tocsr()
    with open(tt, 'wb') as f: pickle.dump(d[s], f)
  return d

# %%
def get_and_save_or_load_sample(train_ratio=0.8, test_ratio=0.2):
  d = dict()
  d = get_and_save_or_load_movies(d)
  d = get_and_save_or_load_users(d, train_ratio, test_ratio)
  d = get_and_save_or_load_maps(d)
  for s in ("test", "train"):
    d = get_and_save_or_load_matrix(d, s)
  return d

# %%
# I added the processed.zip file manually
! unzip processed.zip -d .
# Out:
# Archive:  processed.zip
#    creating: ./content/processed/
#   inflating: ./content/processed/test_users.pkl
#   inflating: ./content/processed/user_to_index.pkl
#   inflating: ./content/processed/all_users.pkl
#   inflating: ./content/processed/train_matrix.pkl
#   inflating: ./content/processed/train_users.pkl
#   inflating: ./content/processed/movie_to_index.pkl
#   inflating: ./content/processed/test_matrix.pkl
#   inflating: ./content/processed/all_movies.pkl

# %%
! mkdir /content/processed
! mv /content/content/processed/* /content/processed/

# %%
! rm -rf /content/content
! rm -rf /content/processed.zip

# %%
import numpy as np
from scipy.sparse import find

def subtract_column(sparse_matrix, column):
    column = column.flatten()
    nonzero_rows, nonzero_cols = sparse_matrix.nonzero()
    nonzero_values = sparse_matrix.data
    nonzero_values -= column[nonzero_rows]
    new_sparse_matrix = sparse_matrix.copy()
    new_sparse_matrix.data[:] = nonzero_values
    return new_sparse_matrix

def demean_matrix(mat):
    sums = mat.sum(axis=1).A1
    counts = np.diff(mat.indptr)
    averages = sums / counts
    averages = averages.reshape(-1, 1)
    return subtract_column(mat, averages)

d = get_and_save_or_load_sample()
d["train_matrix_demeaned"] = demean_matrix(d["train_matrix"].asfptype())
d["test_matrix_demeaned"] = demean_matrix(d["test_matrix"].asfptype())
d["train_matrix_demeaned"].data
# Out:
# <ipython-input-12-93c3e164cf57>:16: RuntimeWarning: invalid value encountered in true_divide
#   averages = sums / counts
# array([ 0.56193742,  0.56193742,  0.56193742, ...,  2.78800631,
#        -0.21199369, -1.21199369])

# %%
print(d["train_matrix"][0])
print(d["train_matrix_demeaned"][0])
print(d["train_matrix"][500])
print(d["train_matrix_demeaned"][500])
# Out:
#   (0, 0)	7
#   (0, 1)	7
#   (0, 2)	7
#   (0, 3)	4
#   (0, 4)	5
#   (0, 5)	5
#   (0, 6)	10
#   (0, 7)	7
#   (0, 8)	7
#   (0, 9)	6
#   (0, 10)	8
#   (0, 11)	6
#   (0, 12)	10
#   (0, 13)	5
#   (0, 14)	7
#   (0, 15)	4
#   (0, 16)	5
#   (0, 17)	8
#   (0, 18)	8
#   (0, 19)	5
#   (0, 20)	8
#   (0, 21)	7
#   (0, 22)	8
#   (0, 23)	4
#   (0, 24)	8
#   :	:
#   (0, 251340)	9
#   (0, 251341)	8
#   (0, 251344)	9
#   (0, 251369)	7
#   (0, 251370)	8
#   (0, 251374)	6
#   (0, 251752)	8
#   (0, 253141)	7
#   (0, 254264)	7
#   (0, 256409)	8
#   (0, 257470)	6
#   (0, 257565)	6
#   (0, 259445)	7
#   (0, 260445)	7
#   (0, 262341)	4
#   (0, 262342)	6
#   (0, 266629)	4
#   (0, 273154)	9
#   (0, 274406)	7
#   (0, 274873)	7
#   (0, 274887)	8
#   (0, 274900)	9
#   (0, 275309)	6
#   (0, 280808)	6
#   (0, 282608)	6
#   (0, 0)	0.5619374196313762
#   (0, 1)	0.5619374196313762
#   (0, 2)	0.5619374196313762
#   (0, 3)	-2.4380625803686238
#   (0, 4)	-1.4380625803686238
#   (0, 5)	-1.4380625803686238
#   (0, 6)	3.5619374196313762
#   (0, 7)	0.5619374196313762
#   (0, 8)	0.5619374196313762
#   (0, 9)	-0.4380625803686238
#   (0, 10)	1.5619374196313762
#   (0, 11)	-0.4380625803686238
#   (0, 12)	3.5619374196313762
#   (0, 13)	-1.4380625803686238
#   (0, 14)	0.5619374196313762
#   (0, 15)	-2.4380625803686238
#   (0, 16)	-1.4380625803686238
#   (0, 17)	1.5619374196313762
#   (0, 18)	1.5619374196313762
#   (0, 19)	-1.4380625803686238
#   (0, 20)	1.5619374196313762
#   (0, 21)	0.5619374196313762
#   (0, 22)	1.5619374196313762
#   (0, 23)	-2.4380625803686238
#   (0, 24)	1.5619374196313762
#   :	:
#   (0, 251340)	2.5619374196313762
#   (0, 251341)	1.5619374196313762
#   (0, 251344)	2.5619374196313762
#   (0, 251369)	0.5619374196313762
#   (0, 251370)	1.5619374196313762
#   (0, 251374)	-0.4380625803686238
#   (0, 251752)	1.5619374196313762
#   (0, 253141)	0.5619374196313762
#   (0, 254264)	0.5619374196313762
#   (0, 256409)	1.5619374196313762
#   (0, 257470)	-0.4380625803686238
#   (0, 257565)	-0.4380625803686238
#   (0, 259445)	0.5619374196313762
#   (0, 260445)	0.5619374196313762
#   (0, 262341)	-2.4380625803686238
#   (0, 262342)	-0.4380625803686238
#   (0, 266629)	-2.4380625803686238
#   (0, 273154)	2.5619374196313762
#   (0, 274406)	0.5619374196313762
#   (0, 274873)	0.5619374196313762
#   (0, 274887)	1.5619374196313762
#   (0, 274900)	2.5619374196313762
#   (0, 275309)	-0.4380625803686238
#   (0, 280808)	-0.4380625803686238
#   (0, 282608)	-0.4380625803686238
#   (0, 1)	8
#   (0, 6)	8
#   (0, 9)	7
#   (0, 11)	5
#   (0, 12)	8
#   (0, 18)	3
#   (0, 23)	9
#   (0, 24)	9
#   (0, 25)	8
#   (0, 26)	7
#   (0, 27)	6
#   (0, 28)	9
#   (0, 29)	8
#   (0, 33)	8
#   (0, 35)	8
#   (0, 36)	5
#   (0, 37)	4
#   (0, 38)	4
#   (0, 40)	2
#   (0, 41)	8
#   (0, 43)	3
#   (0, 45)	6
#   (0, 51)	6
#   (0, 54)	5
#   (0, 58)	8
#   :	:
#   (0, 231281)	4
#   (0, 231288)	4
#   (0, 231402)	7
#   (0, 231424)	3
#   (0, 231439)	3
#   (0, 233674)	5
#   (0, 233677)	3
#   (0, 233938)	3
#   (0, 234671)	4
#   (0, 234717)	4
#   (0, 234750)	1
#   (0, 241082)	6
#   (0, 251101)	7
#   (0, 252253)	1
#   (0, 257655)	4
#   (0, 260141)	9
#   (0, 260445)	8
#   (0, 272743)	3
#   (0, 273154)	9
#   (0, 273483)	8
#   (0, 274174)	3
#   (0, 274795)	1
#   (0, 274858)	8
#   (0, 274873)	4
#   (0, 280572)	6
#   (0, 1)	1.727990525069088
#   (0, 6)	1.727990525069088
#   (0, 9)	0.7279905250690879
#   (0, 11)	-1.272009474930912
#   (0, 12)	1.727990525069088
#   (0, 18)	-3.272009474930912
#   (0, 23)	2.727990525069088
#   (0, 24)	2.727990525069088
#   (0, 25)	1.727990525069088
#   (0, 26)	0.7279905250690879
#   (0, 27)	-0.2720094749309121
#   (0, 28)	2.727990525069088
#   (0, 29)	1.727990525069088
#   (0, 33)	1.727990525069088
#   (0, 35)	1.727990525069088
#   (0, 36)	-1.272009474930912
#   (0, 37)	-2.272009474930912
#   (0, 38)	-2.272009474930912
#   (0, 40)	-4.272009474930912
#   (0, 41)	1.727990525069088
#   (0, 43)	-3.272009474930912
#   (0, 45)	-0.2720094749309121
#   (0, 51)	-0.2720094749309121
#   (0, 54)	-1.272009474930912
#   (0, 58)	1.727990525069088
#   :	:
#   (0, 231281)	-2.272009474930912
#   (0, 231288)	-2.272009474930912
#   (0, 231402)	0.7279905250690879
#   (0, 231424)	-3.272009474930912
#   (0, 231439)	-3.272009474930912
#   (0, 233674)	-1.272009474930912
#   (0, 233677)	-3.272009474930912
#   (0, 233938)	-3.272009474930912
#   (0, 234671)	-2.272009474930912
#   (0, 234717)	-2.272009474930912
#   (0, 234750)	-5.272009474930912
#   (0, 241082)	-0.2720094749309121
#   (0, 251101)	0.7279905250690879
#   (0, 252253)	-5.272009474930912
#   (0, 257655)	-2.272009474930912
#   (0, 260141)	2.727990525069088
#   (0, 260445)	1.727990525069088
#   (0, 272743)	-3.272009474930912
#   (0, 273154)	2.727990525069088
#   (0, 273483)	1.727990525069088
#   (0, 274174)	-3.272009474930912
#   (0, 274795)	-5.272009474930912
#   (0, 274858)	1.727990525069088
#   (0, 274873)	-2.272009474930912
#   (0, 280572)	-0.2720094749309121

# %%
from scipy.sparse.linalg import svds
U, sigma, Vh = svds(d["train_matrix_demeaned"], k=500)
U, sigma, Vh
# Out:
# (array([[ 0.00212523,  0.00151282, -0.00319171, ..., -0.01612611,
#           0.00839345, -0.01589729],
#         [-0.00374893,  0.01278453, -0.00255126, ..., -0.02973947,
#          -0.00684841, -0.01634006],
#         [ 0.00539789, -0.00617903,  0.034954  , ..., -0.01235481,
#          -0.00528474, -0.01589895],
#         ...,
#         [ 0.00656284, -0.00125372,  0.0085012 , ..., -0.01323971,
#           0.00847087, -0.01312287],
#         [ 0.00072445, -0.00394366,  0.00105144, ..., -0.01040594,
#           0.00168204, -0.00668816],
#         [-0.00939986, -0.00715633,  0.01661847, ..., -0.00048983,
#           0.0165631 , -0.01616254]]),
#  array([ 116.54542151,  116.67910475,  116.71982743,  116.7502984 ,
#          116.92202991,  116.92913427,  116.98716484,  117.0767229 ,
#          117.12322094,  117.14408382,  117.20827829,  117.25435961,
#          117.46000482,  117.59227078,  117.61962909,  117.69108463,
#          117.73149586,  117.76780123,  117.84293208,  117.8916043 ,
#          117.98947355,  118.02813776,  118.09088458,  118.18556849,
#          118.22670183,  118.27113174,  118.31917445,  118.32416391,
#          118.44689314,  118.55136831,  118.63291864,  118.68615002,
#          118.70664652,  118.87676218,  118.92884156,  118.98857   ,
#          119.06498155,  119.10787794,  119.16556246,  119.25741476,
#          119.32256241,  119.3974519 ,  119.44009378,  119.46162337,
#          119.54735538,  119.65576813,  119.74891349,  119.88612888,
#          119.94085354,  120.00292816,  120.0171415 ,  120.0898999 ,
#          120.17375754,  120.23193001,  120.30538056,  120.36157905,
#          120.38209623,  120.43408294,  120.55738273,  120.63069557,
#          120.66940265,  120.75673775,  120.83360218,  120.95760383,
#          121.03457565,  121.10555762,  121.15244422,  121.21519052,
#          121.27245861,  121.33762738,  121.45032713,  121.46620285,
#          121.59131465,  121.67143367,  121.75393874,  121.81452493,
#          121.90115921,  121.94331717,  122.03502999,  122.13102581,
#          122.25629885,  122.32092489,  122.3996758 ,  122.45575665,
#          122.54560587,  122.59713255,  122.65872106,  122.77993316,
#          122.87267644,  122.91559618,  123.04503597,  123.08716527,
#          123.15255355,  123.19811989,  123.33254074,  123.43332822,
#          123.52241377,  123.60466954,  123.70334656,  123.76448625,
#          123.80067054,  123.92050052,  124.04695866,  124.11908594,
#          124.16365002,  124.25037002,  124.27487306,  124.37899676,
#          124.44572638,  124.49166228,  124.63002253,  124.75339734,
#          124.79184643,  124.85724396,  124.91929701,  125.04599448,
#          125.15640782,  125.19359697,  125.19873948,  125.30030901,
#          125.47233403,  125.53733715,  125.58919762,  125.72960283,
#          125.74608362,  125.79054706,  125.89643992,  126.05787459,
#          126.16026383,  126.20403761,  126.27779722,  126.29506145,
#          126.47087068,  126.53497236,  126.5494753 ,  126.73255751,
#          126.84361813,  126.9333272 ,  127.03996411,  127.1102017 ,
#          127.19106541,  127.24767262,  127.29389891,  127.43413736,
#          127.58336624,  127.64262424,  127.67229917,  127.83586647,
#          127.924616  ,  127.95295284,  128.07487582,  128.2681694 ,
#          128.33029123,  128.37220165,  128.52135157,  128.54499917,
#          128.6018543 ,  128.62388815,  128.80903949,  128.85204246,
#          129.01060439,  129.10475128,  129.13866175,  129.25513747,
#          129.35443975,  129.40868148,  129.51500354,  129.58092601,
#          129.67553285,  129.74679177,  129.94021591,  129.99693687,
#          130.03372747,  130.20705517,  130.26305734,  130.37178659,
#          130.4063735 ,  130.49843753,  130.72900414,  130.80628519,
#          130.86572117,  130.9444116 ,  131.06706364,  131.17315927,
#          131.24219554,  131.26607548,  131.33987036,  131.45791473,
#          131.55969863,  131.63607481,  131.80992837,  131.95650524,
#          132.04142344,  132.17800568,  132.24323965,  132.35436421,
#          132.53906907,  132.55853533,  132.65391887,  132.71074216,
#          132.78089557,  132.97811197,  132.99061646,  133.11415866,
#          133.27635213,  133.38005486,  133.53276305,  133.68856304,
#          133.76573024,  133.88909779,  133.94623774,  134.01931881,
#          134.07598766,  134.19125502,  134.37601652,  134.49048306,
#          134.58790143,  134.69198598,  134.73648959,  134.85686264,
#          135.00678674,  135.20355962,  135.36113524,  135.47384063,
#          135.59386715,  135.64739131,  135.75842452,  135.94181482,
#          135.98602886,  136.0924872 ,  136.20544077,  136.28835116,
#          136.38785645,  136.52220818,  136.59700702,  136.64697549,
#          136.80988929,  136.97014514,  137.01978234,  137.14069226,
#          137.30557326,  137.48676031,  137.55168205,  137.719105  ,
#          137.820399  ,  137.89379177,  138.03408207,  138.15618316,
#          138.30891222,  138.51522632,  138.63186631,  138.73694193,
#          138.8992235 ,  139.0145387 ,  139.08878455,  139.13303314,
#          139.24313471,  139.37736153,  139.6223948 ,  139.66716824,
#          139.77250555,  139.78917809,  139.93346672,  140.2500007 ,
#          140.44115147,  140.5045673 ,  140.57396891,  140.67420566,
#          140.89818044,  140.97939633,  141.09752076,  141.37816986,
#          141.60707555,  141.71922355,  141.86871204,  141.89217822,
#          141.9866471 ,  142.18449282,  142.29454074,  142.41376851,
#          142.46717481,  142.75009044,  142.8263504 ,  142.96452582,
#          143.1354266 ,  143.31363007,  143.4469684 ,  143.65133427,
#          143.75762861,  143.91446627,  144.09321666,  144.17275715,
#          144.40895447,  144.49052424,  144.59938163,  144.64368906,
#          144.85323923,  145.09828223,  145.3381466 ,  145.38437371,
#          145.55441733,  145.78714972,  145.8431175 ,  146.00831613,
#          146.15952511,  146.4464955 ,  146.51254702,  146.86087112,
#          146.88855599,  147.067784  ,  147.36480751,  147.52734904,
#          147.64070899,  147.77856548,  147.88787885,  148.08065995,
#          148.24621808,  148.59163754,  148.6202654 ,  148.77909237,
#          149.06213215,  149.22381451,  149.27547769,  149.58389576,
#          149.65028701,  149.80935008,  150.25583735,  150.54653326,
#          150.59890615,  150.75164508,  150.99439592,  151.15401817,
#          151.5381418 ,  151.60121486,  151.62878855,  151.7855491 ,
#          152.05416708,  152.23664132,  152.36653752,  152.58676751,
#          152.81525034,  153.05765401,  153.09830629,  153.36748309,
#          153.60546446,  153.91780173,  154.11545516,  154.44476795,
#          154.53487856,  154.90755721,  155.15690288,  155.35513747,
#          155.71389921,  156.07832588,  156.27703892,  156.28406742,
#          156.79002763,  156.86195246,  156.94224337,  157.479042  ,
#          157.62687913,  157.77117373,  158.13278817,  158.33493156,
#          158.53935357,  158.85092899,  159.19598688,  159.51455849,
#          159.82798873,  159.93855515,  160.158304  ,  160.36131483,
#          160.48786833,  160.65286808,  161.74696162,  161.97124021,
#          162.22563869,  162.4357841 ,  162.83119867,  163.00302843,
#          163.29475681,  163.63007398,  164.04063675,  164.17149844,
#          164.51729227,  164.78486028,  165.17344426,  165.5977138 ,
#          165.92716771,  166.35644765,  166.80096242,  166.89625001,
#          167.49645857,  167.83493305,  168.29577106,  168.52840355,
#          168.72066562,  169.64404022,  170.23909091,  170.49548958,
#          171.34751294,  171.58635473,  171.99343621,  172.45296721,
#          172.61455075,  173.56429583,  173.65325384,  173.85739649,
#          174.20161148,  174.96597106,  175.37102917,  175.91305735,
#          176.32325802,  176.95184363,  177.38723835,  177.4808718 ,
#          178.21662312,  179.28386709,  179.80356405,  180.04368505,
#          180.77197307,  181.94631194,  182.22147337,  182.88072812,
#          183.34749047,  183.87393232,  184.33225724,  184.75076244,
#          185.5637426 ,  186.01799392,  186.54061029,  187.30122422,
#          188.45207978,  188.88470203,  189.54420246,  190.38123338,
#          190.98070826,  191.82176719,  192.09520149,  192.90640448,
#          193.35592918,  194.20109015,  194.87638103,  197.01280452,
#          198.33660489,  198.48350608,  199.02822919,  200.93378969,
#          201.69139096,  202.70041964,  204.42721676,  205.21137725,
#          205.93560855,  208.16834263,  209.30656023,  212.17434814,
#          213.03303432,  213.3322642 ,  214.52153671,  215.39158041,
#          218.02262478,  219.2842704 ,  221.39737828,  221.62167869,
#          223.32984437,  224.12643524,  226.57425905,  228.49820348,
#          232.15173864,  234.64219995,  235.5482593 ,  237.58445692,
#          237.90048799,  240.93200244,  243.95708318,  246.58928171,
#          247.71724195,  252.49589177,  255.69025422,  259.95865132,
#          261.92417626,  267.31059669,  276.7709913 ,  282.01850521,
#          286.12037642,  301.24419314,  306.21260284,  326.53891436,
#          354.62295553,  366.57353598,  378.70357522,  401.0490049 ,
#          405.55079248,  433.50965307,  463.03640432,  495.4718934 ,
#          507.32659384,  672.77044898,  823.46866466, 2012.34883325]),
#  array([[ 6.61612267e-03,  1.52993200e-02,  2.15637322e-03, ...,
#          -3.70233650e-05, -9.01958552e-05,  2.82011577e-04],
#         [-1.42297000e-02, -1.23847023e-02, -1.45281552e-03, ...,
#          -8.85373234e-05, -2.15693512e-04,  6.74399806e-04],
#         [ 6.87327014e-03, -4.40855974e-03,  5.79401932e-04, ...,
#           1.48210808e-04,  3.61069303e-04, -1.12894016e-03],
#         ...,
#         [ 6.35608023e-03,  8.49516332e-03, -1.36862316e-04, ...,
#          -7.99626749e-06, -1.94804061e-05,  6.09085642e-05],
#         [ 8.96528377e-03,  4.38999582e-03,  3.59094424e-04, ...,
#           1.81957405e-06,  4.43282338e-06, -1.38599219e-05],
#         [-6.11433714e-03, -3.95757516e-03,  3.54562374e-05, ...,
#          -3.36763121e-06, -8.20418071e-06,  2.56516658e-05]]))

# %%
import warnings
from sklearn.metrics.pairwise import cosine_similarity
def predict_scores(d, uname, num_neighbors, return_dict=False):
    # Get the score array for the user
    user_scores = d["test_matrix"][d["user_to_index"][uname]]

    # Get the average user rating to add it back later
    arr_nonzero_avg = user_scores.sum() / user_scores.count_nonzero()

    # Calculate latent vector by dot product with sigma reciprocal times Vh transpose    
    latent_vector = user_scores.dot(1 / sigma * Vh.transpose())
    
    # Get cosine similarities between latent vector and U
    sims = cosine_similarity(latent_vector, U)
    sims = sims.flatten()

    neighbor_indices = sims.argsort()[::-1][:num_neighbors]
    neighbor_ratings = d["train_matrix"][neighbor_indices, :].toarray().astype('float')
    neighbor_ratings[neighbor_ratings < 0.5] = 'nan'
    with warnings.catch_warnings():
      warnings.simplefilter("ignore", category=RuntimeWarning)
      movie_ratings = np.nanmean(neighbor_ratings, axis=0)  # Ignores NaNs by default
    movie_ratings[np.isnan(movie_ratings)] = arr_nonzero_avg  # Predict avg score when forced
    if return_dict: return {d["all_movies"][i]: movie_ratings[i] for i in range(len(movie_ratings))}
    else: return movie_ratings

import random
uname = random.choice(d["test_users"])
map = predict_scores(d, uname, 100, return_dict=True)
map
# Out:
# {'feast-2014': 8.0,
#  'loving-2016': 7.769230769230769,
#  'scripted-content': 6.0,
#  'the-future': 6.0,
#  'mank': 6.8,
#  'embers-2015': 6.493140243902439,
#  'the-social-network': 8.89655172413793,
#  'miss-you-already': 5.666666666666667,
#  'saw-iii': 5.6521739130434785,
#  'recess-schools-out': 5.333333333333333,
#  'the-girl-on-the-train-2016': 6.129032258064516,
#  'yes-man': 5.894736842105263,
#  'insidious': 6.6875,
#  'the-alphabet': 7.111111111111111,
#  'first-girl-i-loved': 6.5,
#  'red-mist': 3.5,
#  'sydney-white': 3.8,
#  'bo-burnham-what': 6.166666666666667,
#  'all-cheerleaders-die': 4.411764705882353,
#  'the-wave-2015': 7.0,
#  'next-floor': 7.266666666666667,
#  'nerve-2016': 5.333333333333333,
#  'the-disappearance-of-eleanor-rigby-her': 7.333333333333333,
#  'mud': 7.884615384615385,
#  'doubt': 7.7368421052631575,
#  'walk-hard-the-dewey-cox-story': 7.578947368421052,
#  'hush-2016': 6.542857142857143,
#  'deadpool': 7.174603174603175,
#  'the-invitation-2015': 7.142857142857143,
#  'trick-r-treat': 7.28,
#  'queen-of-earth': 6.7272727272727275,
#  'crimson-peak': 7.16,
#  'bitter-orange': 6.493140243902439,
#  'fright-night': 7.777777777777778,
#  'a-charlie-brown-thanksgiving': 7.5,
#  'the-duke-of-burgundy': 7.857142857142857,
#  'v-h-s': 5.142857142857143,
#  'are-we-there-yet': 5.666666666666667,
#  'would-you-rather': 5.045454545454546,
#  'the-shaggy-dog-2006': 1.5,
#  'the-lazarus-effect-2015': 4.571428571428571,
#  'birdman-or-the-unexpected-virtue-of-ignorance': 8.418181818181818,
#  'sleepover': 4.8,
#  'vacation-2015': 4.888888888888889,
#  'saving-silverman': 4.857142857142857,
#  'happy-feet': 5.277777777777778,
#  'cow-belles': 6.0,
#  'lava-2014': 5.916666666666667,
#  'read-it-and-weep': 4.0,
#  'now-you-see-it': 8.0,
#  'halloweentown-high': 5.333333333333333,
#  'spy': 6.536585365853658,
#  'moms-got-a-date-with-a-vampire': 5.0,
#  'tig': 6.493140243902439,
#  'legend-2015': 6.416666666666667,
#  'incendies': 8.263157894736842,
#  'antibirth': 7.0,
#  'kubo-and-the-two-strings': 8.068965517241379,
#  'dont-breathe-2016': 7.130434782608695,
#  'sun-choke': 7.0,
#  'the-bling-ring': 6.206896551724138,
#  'oslo-august-31st': 8.272727272727273,
#  'wet-hot-american-summer': 6.875,
#  'the-conjuring-2': 6.657894736842105,
#  'twister': 7.0,
#  'full-metal-jacket': 8.628571428571428,
#  'batman-v-superman-dawn-of-justice': 5.872727272727273,
#  'trading-mom': 3.0,
#  'the-revenant-2015': 8.11111111111111,
#  'the-wrong-trousers': 6.8,
#  'oliver-company': 5.0,
#  'raise-your-voice': 5.5,
#  'because-of-winn-dixie': 7.0,
#  'lost-river': 7.260869565217392,
#  'good-burger': 5.875,
#  'shark-tale': 5.333333333333333,
#  'homeward-bound-the-incredible-journey': 5.75,
#  'while-you-were-sleeping': 6.25,
#  'bottle-rocket-1996': 6.909090909090909,
#  'fantastic-four': 3.7777777777777777,
#  'tiger-cruise': 6.493140243902439,
#  'full-court-miracle': 4.0,
#  'double-teamed': 6.493140243902439,
#  'macbeth-2015': 7.333333333333333,
#  'paperman': 7.9411764705882355,
#  'struck-by-lightning': 3.5,
#  'the-disappearance-of-eleanor-rigby-him': 7.0,
#  'the-royal-tenenbaums': 8.3,
#  'cronos': 7.2,
#  'short-term-12-2013': 8.527777777777779,
#  'the-way-he-looks': 7.875,
#  'adaptation': 7.935483870967742,
#  'drive-2011': 8.741379310344827,
#  'martha-marcy-may-marlene': 7.384615384615385,
#  'neighbors-2014': 5.8,
#  'freeheld-2015': 6.0,
#  'heaven-knows-what': 7.153846153846154,
#  'room-2015': 8.340425531914894,
#  'what-we-do-in-the-shadows': 8.292307692307693,
#  'madagascar-escape-2-africa': 5.357142857142857,
#  'stardust-2007': 7.428571428571429,
#  'envy': 4.285714285714286,
#  'pontypool': 6.96,
#  'film:181756': 4.5,
#  'dope-2015': 6.7894736842105265,
#  'one-hundred-and-one-dalmatians': 6.166666666666667,
#  'like-mike': 4.0,
#  'getting-there': 6.493140243902439,
#  'getting-even-with-dad': 3.0,
#  'the-land-before-time': 6.5,
#  'the-mist': 7.333333333333333,
#  'god-bless-america': 6.153846153846154,
#  'the-cheetah-girls-2': 7.0,
#  'the-boxtrolls': 6.545454545454546,
#  'coherence': 7.75,
#  'cobain-montage-of-heck': 7.0,
#  'pride-2014': 8.1875,
#  'the-muppets': 7.375,
#  'the-realest-real': 6.493140243902439,
#  'monsters-vs-aliens': 5.647058823529412,
#  'the-diving-bell-and-the-butterfly': 8.88888888888889,
#  'the-purge-anarchy': 6.0,
#  'the-powerpuff-girls-movie': 6.0,
#  'the-nice-guys': 7.948275862068965,
#  'breathe-2014': 7.9,
#  'the-stanford-prison-experiment': 6.909090909090909,
#  'the-machinist': 7.4,
#  'white-god': 7.0,
#  'magic-mike-xxl': 7.1,
#  'the-fountain': 7.65,
#  'the-city-of-lost-children': 7.5,
#  'the-summer-of-sangaile': 5.0,
#  'the-devil-wears-prada': 6.88,
#  'joy-2015': 6.142857142857143,
#  'john-mulaney-the-comeback-kid': 8.0,
#  'american-ultra': 6.208333333333333,
#  'the-aristocats': 6.1875,
#  'the-blob-1988': 7.962962962962963,
#  'tower-of-terror': 6.493140243902439,
#  'good-boy': 6.493140243902439,
#  'camp-takota': 6.493140243902439,
#  'enemy': 7.958333333333333,
#  'king-of-california': 7.0,
#  'eagle-eye': 5.363636363636363,
#  'teachers-pet-2004': 6.0,
#  'dinosaur': 5.555555555555555,
#  'cool-runnings': 6.111111111111111,
#  'high-school-musical-2': 5.714285714285714,
#  'honey-i-blew-up-the-kid': 4.4,
#  'serving-sara': 2.3333333333333335,
#  'tracks-2013': 7.571428571428571,
#  'going-clear-scientology-and-the-prison-of-belief': 7.6,
#  'stuck-in-the-suburbs': 6.493140243902439,
#  'pixel-perfect': 6.493140243902439,
#  'the-scream-team': 6.0,
#  'right-on-track': 3.0,
#  'the-luck-of-the-irish': 6.493140243902439,
#  'pitch-perfect-2': 5.647058823529412,
#  'schindlers-list': 8.962962962962964,
#  'a-girl-walks-home-alone-at-night': 7.172413793103448,
#  'firestarter': 6.75,
#  'gentlemen-broncos': 6.166666666666667,
#  'the-great-outdoors': 7.375,
#  'my-own-private-idaho': 7.722222222222222,
#  'safe': 7.9411764705882355,
#  'finding-dory': 6.45945945945946,
#  'jurassic-world': 6.7,
#  'sisters-2015': 5.7368421052631575,
#  'its-the-great-pumpkin-charlie-brown': 8.666666666666666,
#  'creep-2014': 6.416666666666667,
#  'martyrs': 7.827586206896552,
#  'the-heart-machine': 5.0,
#  'the-abandoned': 5.0,
#  'the-adventures-of-pinocchio-1996': 2.0,
#  'treasure-planet': 6.083333333333333,
#  'cinderella': 6.117647058823529,
#  'surviving-christmas': 3.25,
#  'flubber': 3.857142857142857,
#  'sorority-boys': 6.493140243902439,
#  'the-wedding-planner': 3.6,
#  'the-age-of-adaline': 5.8,
#  'lets-go-to-prison': 4.0,
#  'comet': 6.75,
#  'twitches': 5.5,
#  'going-to-the-mat': 6.493140243902439,
#  'hounded': 6.493140243902439,
#  'leon-the-professional': 8.685714285714285,
#  'the-brooke-ellison-story': 6.493140243902439,
#  'american-beauty': 7.2368421052631575,
#  'dear-zachary-a-letter-to-a-son-about-his-father': 8.5,
#  'hunger': 7.875,
#  'monster': 6.5,
#  'into-the-forest': 5.0,
#  'i-will-follow': 2.0,
#  'closer': 7.3125,
#  'hard-candy': 6.5,
#  'i-believe-in-unicorns': 4.5,
#  'taxi-driver': 8.867924528301886,
#  'tom-at-the-farm': 6.9,
#  'kumiko-the-treasure-hunter': 5.75,
#  'high-school-musical': 5.5,
#  'over-the-hedge': 5.857142857142857,
#  'insidious-chapter-3': 5.55,
#  'the-final-girls': 6.75,
#  'the-hills-have-eyes-2006': 6.9411764705882355,
#  'the-martian': 7.896551724137931,
#  'beginners': 8.0,
#  'a-simple-wish': 5.0,
#  'pirates-of-the-caribbean-at-worlds-end': 5.409090909090909,
#  'bedtime-stories': 5.454545454545454,
#  'problem-child': 5.111111111111111,
#  'jack-frost': 4.142857142857143,
#  'little-manhattan': 6.0,
#  'snow-dogs': 3.0,
#  'the-master-of-disguise': 3.0,
#  'final-destination-2': 6.052631578947368,
#  'the-man-from-uncle': 6.634146341463414,
#  'the-even-stevens-movie': 6.493140243902439,
#  'horse-sense': 6.493140243902439,
#  'under-wraps': 6.0,
#  'contact': 7.5,
#  'honeymoon-2014': 7.0,
#  'pretty-persuasion': 4.0,
#  'my-summer-of-love': 6.0,
#  'the-guest-2014': 7.708333333333333,
#  'la-la-land': 8.578947368421053,
#  'cache': 8.222222222222221,
#  'wiener-dog': 6.2,
#  'celeste-jesse-forever': 5.714285714285714,
#  'december-boys': 5.5,
#  'blue-valentine': 8.085714285714285,
#  'starlet': 7.555555555555555,
#  'the-life-aquatic-with-steve-zissou': 7.457142857142857,
#  'the-fly-1986': 8.636363636363637,
#  'a-walk-to-remember': 6.1,
#  'midnight-special': 7.303030303030303,
#  'boogie-nights': 8.978260869565217,
#  'the-big-short': 7.625,
#  'carol-2015': 8.114285714285714,
#  'chicken-run': 7.333333333333333,
#  'the-loved-ones': 7.2272727272727275,
#  'young-ones': 6.5,
#  'laurence-anyways': 8.0,
#  'waterworld': 5.928571428571429,
#  'north': 2.0,
#  'tom-and-huck': 6.493140243902439,
#  'beethovens-2nd': 3.0,
#  'mr-woodcock': 3.0,
#  'wendy-wu-homecoming-warrior': 7.0,
#  'jump-in': 4.0,
#  'you-wish': 6.493140243902439,
#  'jumping-ship': 6.493140243902439,
#  'the-color-of-friendship': 6.493140243902439,
#  'inside-out-2015': 8.509803921568627,
#  'alps': 7.166666666666667,
#  'happiest-season': 6.3076923076923075,
#  'closet-monster': 8.333333333333334,
#  'hunt-for-the-wilderpeople': 8.0,
#  'polytechnique': 7.875,
#  'hail-caesar-2016': 6.6,
#  'storks': 6.0,
#  'train-to-busan': 7.555555555555555,
#  'coyote-ugly': 5.25,
#  'city-of-god': 9.066666666666666,
#  'slap-her-shes-french': 2.0,
#  'the-intervention-2016': 6.0,
#  'the-purge': 4.388888888888889,
#  'men-in-black': 6.826086956521739,
#  'tallulah': 5.8,
#  'money-monster': 6.473684210526316,
#  'austin-powers-in-goldmember': 6.473684210526316,
#  'batman-assault-on-arkham': 6.142857142857143,
#  'son-of-saul': 8.833333333333334,
#  'babel-2006': 6.947368421052632,
#  'ghostbusters': 8.051282051282051,
#  'me-and-you-and-everyone-we-know': 6.166666666666667,
#  'the-lobster': 8.020408163265307,
#  'the-fundamentals-of-caring': 6.466666666666667,
#  'only-god-forgives': 7.319148936170213,
#  'antichrist': 6.5,
#  'high-rise-2015': 6.419354838709677,
#  'the-departed': 8.7,
#  'take-shelter': 8.666666666666666,
#  'a-league-of-their-own': 7.428571428571429,
#  'steve-jobs': 7.837209302325581,
#  'mosquita-y-mari': 6.493140243902439,
#  'what-a-girl-wants': 4.0,
#  'the-hateful-eight': 8.018181818181818,
#  'nanny-mcphee': 5.142857142857143,
#  'the-gift-2015-1': 7.133333333333334,
#  'practical-magic': 6.454545454545454,
#  'the-strangers': 6.2,
#  'shrek-2': 6.44,
#  'the-ward': 4.722222222222222,
#  'indiana-jones-and-the-kingdom-of-the-crystal-skull': 5.290322580645161,
#  'chicken-little-2005': 4.0,
#  'mysterious-skin': 7.9,
#  'the-fox-and-the-hound': 6.0,
#  'snow-day': 4.666666666666667,
#  'home-on-the-range': 4.166666666666667,
#  'leave-it-to-beaver': 5.0,
#  'preservation': 4.2,
#  'bringing-down-the-house': 3.5,
#  'hick': 4.8,
#  'the-benchwarmers': 3.2,
#  'i-robot': 5.625,
#  'aquamarine': 5.428571428571429,
#  'tuck-everlasting': 6.0,
#  'smart-house': 2.5,
#  'johnny-tsunami': 6.493140243902439,
#  'demetri-martin-live-at-the-time': 6.493140243902439,
#  'minions': 5.086956521739131,
#  'atonement': 8.620689655172415,
#  'zenon-z3': 6.493140243902439,
#  'trainwreck': 6.115384615384615,
#  'rip-girls': 6.493140243902439,
#  'genius': 4.0,
#  'the-cutting-edge-the-magic-of-movie-editing': 6.493140243902439,
#  'confessions-of-a-teenage-drama-queen': 5.25,
#  'girlhood-2014': 7.846153846153846,
#  'swiss-army-man': 7.181818181818182,
#  'blair-witch': 4.78125,
#  'room-237': 6.476190476190476,
#  'the-light-between-oceans': 6.75,
#  '52-tuesdays': 6.493140243902439,
#  'rust-and-bone': 7.882352941176471,
#  'the-neon-demon': 7.020408163265306,
#  'spotlight': 8.16326530612245,
#  'the-conformist': 8.4,
#  'anatomy-of-a-love-seen': 6.493140243902439,
#  'funny-games': 7.1923076923076925,
#  'home-alone-4': 1.3333333333333333,
#  'bronson': 7.828571428571428,
#  'planes': 5.0,
#  'heavyweights': 7.0,
#  'my-bosss-daughter': 2.8,
#  'pariah': 8.166666666666666,
#  'magnolia': 8.827586206896552,
#  'halloweentown-ii-kalabars-revenge': 5.25,
#  'the-other-me': 6.493140243902439,
#  'mamas-boy': 4.0,
#  'just-friends': 5.230769230769231,
#  'they-came-together': 6.785714285714286,
#  'ammonite': 6.0,
#  'inside-2007': 7.8,
#  '13th': 8.333333333333334,
#  'under-the-shadow': 6.684210526315789,
#  'clockstoppers': 3.0,
#  'the-hamiltons': 4.571428571428571,
#  'miss-peregrines-home-for-peculiar-children': 5.45,
#  'junebug': 7.166666666666667,
#  'the-tribe-2014': 7.5,
#  'popstar-never-stop-never-stopping': 6.897435897435898,
#  'jennifers-body': 6.404761904761905,
#  'green-room': 7.885245901639344,
#  'kingsman-the-secret-service': 7.766666666666667,
#  '88': 6.493140243902439,
#  'chelsea-peretti-one-of-the-greats': 6.493140243902439,
#  'hellboy': 6.962962962962963,
#  'orphan': 6.428571428571429,
#  'the-other-sister': 6.493140243902439,
#  'me-and-earl-and-the-dying-girl': 7.384615384615385,
#  'quarantine': 6.0,
#  'rv': 4.125,
#  'billboard-dad': 1.0,
#  'the-forgotten-2004': 5.5,
#  'wish-upon-a-star': 6.493140243902439,
#  'kim-possible-a-sitch-in-time': 6.493140243902439,
#  'a-ring-of-endless-light': 6.493140243902439,
#  'brink': 6.493140243902439,
#  'tomboy-2011': 8.0,
#  'the-high-note': 6.166666666666667,
#  'los-angeles-plays-itself': 7.5,
#  'the-fits': 7.3076923076923075,
#  'the-witches-of-eastwick': 6.0,
#  'our-idiot-brother': 6.142857142857143,
#  'fantastic-mr-fox': 8.675,
#  'carnage': 7.368421052631579,
#  'the-piano': 7.071428571428571,
#  'the-shawshank-redemption': 8.38888888888889,
#  'bridge-of-spies': 7.4375,
#  'the-tree-of-life-2011': 8.375,
#  'somewhere': 8.166666666666666,
#  'weighting': 7.0,
#  'brooklyn': 7.931034482758621,
#  'bone-tomahawk': 7.75,
#  'a-cinderella-story': 5.9,
#  'enchanted': 6.65,
#  'carriers': 6.0,
#  'the-green-inferno': 5.576923076923077,
#  'antz': 5.2727272727272725,
#  'sleeping-beauty': 6.555555555555555,
#  'grace': 5.714285714285714,
#  'a-bugs-life': 5.956521739130435,
#  'cyberbully': 3.2,
#  'jungle-2-jungle': 3.0,
#  'the-cat-in-the-hat-2003': 3.6875,
#  'addicted-to-fresno': 5.0,
#  'quints': 6.493140243902439,
#  'welcome-to-me': 5.285714285714286,
#  'get-a-clue': 6.0,
#  'starry-eyes': 7.208333333333333,
#  'piper': 7.555555555555555,
#  '1408': 6.32,
#  'the-eye-2008': 3.4,
#  'thirst-2009': 7.2727272727272725,
#  'the-babadook': 7.407407407407407,
#  'a-separation': 9.071428571428571,
#  'star-trek-beyond': 6.925,
#  'the-shallows': 6.555555555555555,
#  'triple-9': 5.809523809523809,
#  'children-of-men': 8.808510638297872,
#  'as-above-so-below-2014': 6.448275862068965,
#  'phoenix-2014': 7.454545454545454,
#  'mustang-2015': 7.928571428571429,
#  'film:253053': 5.0,
#  'appropriate-behavior': 6.666666666666667,
#  'the-danish-girl': 5.933333333333334,
#  'harry-and-the-hendersons': 5.0,
#  'titanic-1997': 7.4375,
#  'the-game': 7.484848484848484,
#  'john-carter': 6.304347826086956,
#  'the-many-adventures-of-winnie-the-pooh': 7.0,
#  'problem-child-2': 6.75,
#  'bambi': 6.882352941176471,
#  'say-it-isnt-so': 5.0,
#  'its-pat': 2.5,
#  'hoot': 6.333333333333333,
#  'grey-gardens': 7.333333333333333,
#  'life-itself': 7.611111111111111,
#  'motocrossed': 6.493140243902439,
#  'mad-max-fury-road': 8.984375,
#  'four-rooms': 5.2,
#  'cosmopolis': 5.533333333333333,
#  'fantastic-beasts-and-where-to-find-them': 6.333333333333333,
#  'lore': 7.666666666666667,
#  'the-indian-in-the-cupboard': 5.4,
#  'american-honey': 7.269230769230769,
#  'mama-2013': 5.724137931034483,
#  'laid-to-rest': 5.9,
#  'summertime-2015': 7.0,
#  'i-am-not-a-serial-killer': 6.75,
#  'natural-born-killers': 7.157894736842105,
#  'bad-moms': 4.833333333333333,
#  'visions-2015': 3.75,
#  'the-secret-life-of-pets': 5.172413793103448,
#  'the-skin-i-live-in': 7.913043478260869,
#  'you-are-not-alone-2016': 6.493140243902439,
#  'kissing-jessica-stein': 8.0,
#  'faults': 6.916666666666667,
#  'a-single-man': 8.1875,
#  '10-cloverfield-lane': 7.827586206896552,
#  'home-alone': 7.555555555555555,
#  'youth-in-revolt': 5.916666666666667,
#  'chitty-chitty-bang-bang': 5.75,
#  'bee-movie': 5.846153846153846,
#  'robots': 5.0,
#  'primer': 7.464285714285714,
#  'homeward-bound-ii-lost-in-san-francisco': 7.0,
#  'taking-5': 6.493140243902439,
#  'fat-albert': 6.493140243902439,
#  'elena-undone': 6.493140243902439,
#  'that-thing-you-do': 7.0,
#  'from-dusk-till-dawn': 7.628571428571429,
#  'tru-confessions': 6.493140243902439,
#  'stepsister-from-planet-weird': 5.0,
#  'up-up-and-away': 6.493140243902439,
#  'the-hot-chick': 3.3333333333333335,
#  'saw': 6.975,
#  'happiness': 7.764705882352941,
#  'amanda-knox': 6.928571428571429,
#  'evolution-2015': 6.875,
#  'tickled': 7.625,
#  'the-watch-2012': 4.411764705882353,
#  'morgan-2016': 5.1,
#  'how-the-grinch-stole-christmas': 8.1,
#  'the-kid-with-a-bike': 8.0,
#  'the-handmaiden': 8.78048780487805,
#  'lights-out-2016': 5.428571428571429,
#  'austin-powers-international-man-of-mystery': 6.769230769230769,
#  'where-the-wild-things-are': 7.428571428571429,
#  'equals': 5.333333333333333,
#  'neighbors-2-sorority-rising': 5.625,
#  'the-keeping-room': 6.5,
#  'the-overnight': 6.25,
#  'turbo-kid': 7.476190476190476,
#  'mistress-america': 7.161290322580645,
#  'citizen-kane': 8.65625,
#  'maniac-2012': 6.571428571428571,
#  'goodnight-mommy': 7.0,
#  'wetlands-2013-1': 6.0,
#  'elf': 7.5,
#  'the-baby-sitters-club': 6.493140243902439,
#  'dark-ride': 4.857142857142857,
#  'without-a-paddle': 4.0,
#  'are-we-done-yet': 6.493140243902439,
#  'synecdoche-new-york': 8.129032258064516,
#  'national-lampoons-vacation': 7.0,
#  'the-thirteenth-year': 6.493140243902439,
#  'bewitched-2005': 5.230769230769231,
#  'itty-bitty-titty-committee': 6.493140243902439,
#  'frank-2014': 7.166666666666667,
#  'eyes-wide-shut': 8.227272727272727,
#  'the-imitation-game': 7.166666666666667,
#  'still-alice': 6.75,
#  'drop-dead-fred': 7.4,
#  'better-than-chocolate': 6.493140243902439,
#  'when-in-rome': 5.0,
#  'mulholland-drive': 8.422222222222222,
#  'the-hobbit-the-battle-of-the-five-armies': 6.357142857142857,
#  'planes-trains-and-automobiles': 7.88,
#  'the-collector-2009': 6.375,
#  'this-film-is-not-yet-rated': 7.2,
#  'scooby-doo-2-monsters-unleashed': 4.6923076923076925,
#  'fanboys': 6.833333333333333,
#  'bring-it-on-again': 6.493140243902439,
#  'lords-of-dogtown': 7.2,
#  'the-sisterhood-of-the-traveling-pants': 6.0,
#  'four-christmases': 4.428571428571429,
#  '27-dresses': 4.7,
#  'dead-snow': 6.35,
#  'step-brothers': 6.909090909090909,
#  'the-impossible': 6.578947368421052,
#  'freak-city': 6.493140243902439,
#  'sinister': 6.341463414634147,
#  'the-devils-backbone': 7.9,
#  'rec': 7.818181818181818,
#  'dumbo': 6.6,
#  'not-another-teen-movie': 5.764705882352941,
#  'scooby-doo': 5.421052631578948,
#  'hook': 6.105263157894737,
#  'deadgirl': 6.777777777777778,
#  'snow-white-and-the-seven-dwarfs': 6.45,
#  'pineapple-express': 7.392857142857143,
#  'the-secret-life-of-walter-mitty-2013': 6.291666666666667,
#  'role-models': 6.888888888888889,
#  'savages-2012': 5.4375,
#  'the-double-2013': 7.166666666666667,
#  'black-swan': 8.5625,
#  'the-virgin-suicides': 7.666666666666667,
#  'the-waterboy': 5.866666666666666,
#  'election': 7.75,
#  'girl-interrupted': 7.083333333333333,
#  'our-lips-are-sealed': 3.3333333333333335,
#  'the-challenge-2003': 6.493140243902439,
#  'heartbeats': 7.5,
#  'the-darjeeling-limited': 7.7272727272727275,
#  'cake-2014': 7.0,
#  'selena': 5.75,
#  'miss-congeniality-2-armed-and-fabulous': 3.6666666666666665,
#  'stuart-little-2': 4.2,
#  'music-and-lyrics': 7.181818181818182,
#  'dude-wheres-my-car': 5.25,
#  'freaky-friday-1995': 6.493140243902439,
#  'the-box-2009': 5.8,
#  'the-number-23': 3.6153846153846154,
#  'national-lampoons-christmas-vacation': 7.702702702702703,
#  'the-hangover': 6.9655172413793105,
#  'hes-just-not-that-into-you': 4.3,
#  'ruby-sparks': 6.625,
#  'smashed': 6.8,
#  'brothers-2009': 6.785714285714286,
#  'true-romance': 8.387096774193548,
#  'this-is-spinal-tap': 8.291666666666666,
#  'the-other-woman-2014': 4.545454545454546,
#  'the-amazing-spider-man': 6.5777777777777775,
#  'apocalypse-now': 9.714285714285714,
#  'no-country-for-old-men': 8.744186046511627,
#  'super-8': 7.057142857142857,
#  'spider-man': 6.8,
#  'horrible-bosses-2': 5.15,
#  'in-your-eyes-2014': 5.5,
#  'being-john-malkovich': 8.393939393939394,
#  'johnny-mnemonic': 5.666666666666667,
#  'bridge-to-terabithia': 5.909090909090909,
#  'freaky-friday-2003': 5.8125,
#  'the-rocker': 5.833333333333333,
#  'mad-money': 7.0,
#  'the-invention-of-lying': 5.615384615384615,
#  'bride-wars': 4.6,
#  'new-years-eve': 4.166666666666667,
#  'the-midnight-meat-train': 5.75,
#  'green-lantern': 3.75,
#  'ripd': 3.235294117647059,
#  'the-skeleton-key': 5.785714285714286,
#  'jacobs-ladder': 8.043478260869565,
#  'the-orphanage': 7.526315789473684,
#  'night-of-the-living-dead': 8.628571428571428,
#  'when-harry-met-sally': 7.962962962962963,
#  'speed': 7.615384615384615,
#  'the-town': 7.896551724137931,
#  'total-recall-2012': 5.44,
#  'stand-by-me': 8.117647058823529,
#  'anchorman-the-legend-of-ron-burgundy': 7.032258064516129,
#  'avatar': 6.470588235294118,
#  'final-destination-3': 5.6521739130434785,
#  'the-perks-of-being-a-wallflower': 6.488372093023256,
#  'the-great-gatsby-2013': 6.264705882352941,
#  'american-history-x': 7.666666666666667,
#  'the-breakfast-club': 7.333333333333333,
#  'scarface-1983': 8.44,
#  'this-is-the-end': 7.088888888888889,
#  'shutter-island': 7.979591836734694,
#  'psycho': 8.96,
#  'back-to-the-future': 8.729166666666666,
#  'the-lego-movie': 7.711538461538462,
#  'the-lonely-guy': 6.0,
#  'the-parent-trap': 7.5,
#  'one-missed-call-2008': 2.75,
#  'john-mulaney-new-in-town': 8.333333333333334,
#  'red-dawn-2012': 3.769230769230769,
#  'the-collection': 4.923076923076923,
#  'jack-1996': 3.142857142857143,
#  'date-movie': 1.8,
#  'marci-x': 6.493140243902439,
#  'george-of-the-jungle': 4.75,
#  'grindhouse': 8.583333333333334,
#  'along-came-polly': 5.214285714285714,
#  'the-brady-bunch-movie': 7.125,
#  'changeling': 7.142857142857143,
#  'the-boondock-saints-ii-all-saints-day': 5.833333333333333,
#  'fever-pitch-2005': 4.333333333333333,
#  'identity-thief': 3.769230769230769,
#  'final-destination': 6.346153846153846,
#  'the-vanishing': 7.9375,
#  'harry-potter-and-the-prisoner-of-azkaban': 8.446808510638299,
#  'what-happens-in-vegas': 3.3846153846153846,
#  'coraline': 7.928571428571429,
#  'airplane': 7.575757575757576,
#  'fruitvale-station': 7.647058823529412,
#  'youre-next': 6.777777777777778,
#  'ferris-buellers-day-off': 7.8,
#  'happy-gilmore': 6.526315789473684,
#  'harold-kumar-go-to-white-castle': 7.0,
#  'the-truman-show': 8.414634146341463,
#  'mommy-2014': 8.68,
#  'jupiter-ascending': 4.935483870967742,
#  'waynes-world': 7.095238095238095,
#  'strange-wilderness': 4.0,
#  'dennis-the-menace': 4.666666666666667,
#  'big-fat-liar': 5.666666666666667,
#  'nick-offerman-american-ham': 6.493140243902439,
#  'stuck-on-you': 4.666666666666667,
#  'saved': 6.8,
#  'walle': 8.0,
#  'beethoven': 4.0,
#  'joe-versus-the-volcano': 5.857142857142857,
#  'i-now-pronounce-you-chuck-larry': 3.3529411764705883,
#  'bad-news-bears': 5.428571428571429,
#  'my-girl-2': 4.75,
#  'the-artist': 7.15,
#  'house-of-wax-2005': 6.0476190476190474,
#  'love-other-drugs': 6.0,
#  '101-dalmatians': 4.5,
#  'a-christmas-story-1983': 7.578947368421052,
#  'ella-enchanted': 6.9,
#  'meet-the-parents': 6.578947368421052,
#  'pulse-2006': 3.75,
#  'the-others': 6.904761904761905,
#  'jumper': 4.357142857142857,
#  'bachelorette': 4.0,
#  'gamer': 4.857142857142857,
#  'west-side-story': 7.277777777777778,
#  'in-a-world': 5.777777777777778,
#  'the-crazies-2010': 7.153846153846154,
#  'tenacious-d-in-the-pick-of-destiny': 6.181818181818182,
#  'wind-chill': 5.111111111111111,
#  'year-one': 3.6153846153846154,
#  'movie-43': 2.4,
#  'sunshine-cleaning': 6.555555555555555,
#  'the-little-mermaid': 6.818181818181818,
#  'get-him-to-the-greek': 5.722222222222222,
#  'i-am-legend': 6.625,
#  'the-big-year': 5.5,
#  'pirates-of-the-caribbean-dead-mans-chest': 6.08,
#  'friends-with-benefits': 5.3,
#  'the-spectacular-now': 6.888888888888889,
#  'boys-dont-cry': 6.25,
#  'the-incredibles': 7.947368421052632,
#  'upside-down-2012': 6.0,
#  'the-conjuring': 7.372549019607843,
#  'sweeney-todd-the-demon-barber-of-fleet-street-2007': 6.88,
#  'marie-antoinette-2006': 7.086956521739131,
#  'the-wizard-of-oz-1939': 8.076923076923077,
#  'bad-teacher': 4.6,
#  'burn-after-reading': 7.483870967741935,
#  'up-in-the-air': 7.642857142857143,
#  'pirates-of-the-caribbean-the-curse-of-the-black-pearl': 7.205882352941177,
#  'never-let-me-go-2010': 7.6,
#  'detention-2011': 6.458333333333333,
#  'the-heat': 5.869565217391305,
#  'hackers': 6.4,
#  'bring-it-on': 6.2,
#  'holiday-in-the-sun': 2.0,
#  'just-like-heaven': 5.0,
#  'hide-and-seek': 5.125,
#  'baby-geniuses': 1.6666666666666667,
#  'sky-high-2005': 5.571428571428571,
#  'young-adult': 6.458333333333333,
#  'night-at-the-museum-battle-of-the-smithsonian': 5.642857142857143,
#  'nims-island': 4.666666666666667,
#  'fools-gold-2008': 3.5714285714285716,
#  'ghosts-of-girlfriends-past': 4.0,
#  'dream-house': 4.615384615384615,
#  'final-destination-5': 5.625,
#  'take-me-home-tonight': 5.5,
#  'jackass-presents-bad-grandpa': 5.571428571428571,
#  'crazy-stupid-love': 7.290322580645161,
#  'addams-family-values': 6.857142857142857,
#  'friday-the-13th': 7.108108108108108,
#  'dracula-1992': 7.354838709677419,
#  'galaxy-quest': 7.6,
#  'oculus': 6.6571428571428575,
#  'charlie-and-the-chocolate-factory': 5.071428571428571,
#  'brave-2012': 6.2727272727272725,
#  'finding-nemo': 7.5,
#  'moon': 8.272727272727273,
#  'memento': 8.155555555555555,
#  'i-love-you-man': 6.823529411764706,
#  'the-cabin-in-the-woods': 7.509090909090909,
#  'a-charlie-brown-christmas': 8.4,
#  'unbroken': 7.25,
#  'welcome-to-the-dollhouse': 7.0,
#  'im-reed-fish': 5.0,
#  'james-and-the-giant-peach': 5.7,
#  'the-hobbit-the-desolation-of-smaug': 7.209302325581396,
#  'evan-almighty': 4.466666666666667,
#  '17-again': 5.416666666666667,
#  'paper-heart': 6.75,
#  'night-train-2009': 6.0,
#  'you-again': 4.333333333333333,
#  'project-x-2012': 6.111111111111111,
#  'john-dies-at-the-end': 6.782608695652174,
#  'uptown-girls': 7.333333333333333,
#  'new-york-i-love-you': 3.8,
#  'the-sasquatch-gang': 6.493140243902439,
#  'daybreakers': 6.0,
#  'heavenly-creatures': 7.363636363636363,
#  'phantasm': 7.956521739130435,
#  'the-last-house-on-the-left': 5.583333333333333,
#  'mermaids': 7.333333333333333,
#  '8-mile': 6.6923076923076925,
#  'walk-the-line': 7.761904761904762,
#  'anchorman-2-the-legend-continues': 5.586206896551724,
#  'shrek': 6.90625,
#  'beauty-and-the-beast-1991': 7.428571428571429,
#  'suspiria': 8.666666666666666,
#  '127-hours': 7.875,
#  'snowpiercer': 7.704918032786885,
#  'lost-in-translation': 8.236842105263158,
#  'wristcutters-a-love-story': 6.5,
#  'miss-congeniality': 5.0,
#  'charlies-angels-full-throttle': 4.636363636363637,
#  'whiplash-2014': 9.333333333333334,
#  'silent-house': 5.181818181818182,
#  'the-sixth-sense': 7.3428571428571425,
#  'wild': 7.3076923076923075,
#  'little-nicky': 4.090909090909091,
#  'valentines-day': 3.7142857142857144,
#  'mrs-doubtfire': 7.615384615384615,
#  'the-lifeguard': 6.0,
#  'jarhead': 6.833333333333333,
#  'lars-and-the-real-girl': 7.541666666666667,
#  'battle-royale': 8.0,
#  'the-fall': 7.7272727272727275,
#  'uncle-buck': 7.777777777777778,
#  'just-married': 4.8,
#  'high-fidelity': 7.958333333333333,
#  'pinocchio': 6.75,
#  'your-sisters-sister': 5.5,
#  'alice-in-wonderland-2010': 4.851851851851852,
#  '28-days-later': 7.767441860465116,
#  'o-brother-where-art-thou': 7.714285714285714,
#  'aladdin': 7.32,
#  'adventureland': 7.0,
#  'spring-breakers': 7.395833333333333,
#  'blade-runner': 8.69811320754717,
#  'beetlejuice': 7.891891891891892,
#  'i-cant-think-straight': 4.0,
#  'passport-to-paris': 4.666666666666667,
#  'urban-legend': 5.4375,
#  'i-origins': 7.625,
#  'lost-and-delirious': 6.0,
#  '12-and-holding': 6.493140243902439,
#  'side-by-side-2012': 7.142857142857143,
#  'imagine-me-you': 6.5,
#  'watchmen': 7.5675675675675675,
#  'feast-ii-sloppy-seconds': 5.2,
#  'paranoid-park': 6.428571428571429,
#  'i-am-sam': 4.428571428571429,
#  'drillbit-taylor': 4.0,
#  'cirque-du-freak-the-vampires-assistant': 5.333333333333333,
#  'when-in-rome-2010': 4.833333333333333,
#  'couples-retreat': 4.357142857142857,
#  'magic-mike': 6.515151515151516,
#  'source-code': 7.333333333333333,
#  'tammy': 4.166666666666667,
#  'bonnie-and-clyde': 7.857142857142857,
#  'the-lost-boys': 7.833333333333333,
#  'definitely-maybe': 6.25,
#  'the-village': 6.555555555555555,
#  'were-the-millers': 6.0,
#  'interview-with-the-vampire': 6.791666666666667,
#  'midnight-in-paris': 7.964285714285714,
#  'veronica-mars': 7.333333333333333,
#  'carrie-1976': 8.116279069767442,
#  'shame-2011': 8.447368421052632,
#  'under-the-skin-2013': 7.781818181818182,
#  'spider-man-2': 7.219512195121951,
#  'the-sweetest-thing': 5.285714285714286,
#  'the-wedding-singer': 6.777777777777778,
#  'i-killed-my-mother': 7.0,
#  'groundhog-day': 8.513513513513514,
#  'the-adventures-of-sharkboy-and-lavagirl': 4.428571428571429,
#  'kill-bill-the-whole-bloody-affair': 8.25,
#  'session-9': 6.826086956521739,
#  'the-flintstones': 3.0,
#  'lady-in-the-water': 4.3076923076923075,
#  'kindergarten-cop': 5.769230769230769,
#  'white-chicks': 4.083333333333333,
#  'the-witches': 7.3076923076923075,
#  '9': 6.75,
#  'the-bad-news-bears': 6.6,
#  'stuart-little': 5.6,
#  'be-kind-rewind': 6.461538461538462,
#  'madagascar': 5.647058823529412,
#  'liar-liar': 5.65,
#  'the-sitter': 4.842105263157895,
#  'the-east': 6.285714285714286,
#  'the-ramen-girl': 6.0,
#  'josie-and-the-pussycats': 6.5,
#  'the-matrix': 8.357142857142858,
#  'tarzan': 6.125,
#  'jumanji': 6.25,
#  'toy-story-2': 8.066666666666666,
#  'monsters-inc': 7.787878787878788,
#  'submarine': 7.434782608695652,
#  'requiem-for-a-dream': 8.11111111111111,
#  'big-fish': 7.041666666666667,
#  'duplex': 4.714285714285714,
#  'loving-annabelle': 4.0,
#  'new-york-minute': 5.75,
#  'the-switch': 4.5,
#  'scream-4': 5.95,
#  'visions-of-light': 6.493140243902439,
#  'the-sisterhood-of-the-traveling-pants-2': 5.333333333333333,
#  'vantage-point': 5.142857142857143,
#  'shrek-the-third': 5.1875,
#  'whats-eating-gilbert-grape': 7.5,
#  'red-riding-hood-2011': 5.0,
#  'all-good-things': 6.0,
#  'casper': 5.25,
#  'ginger-snaps': 7.423076923076923,
#  'funny-games-2007': 6.791666666666667,
#  'waiting': 5.8,
#  'romeo-juliet-1996': 5.875,
#  'war-of-the-worlds': 6.785714285714286,
#  'the-monuments-men': 4.7894736842105265,
#  'the-princess-bride': 8.0,
#  'the-spirit': 4.0,
#  'legally-blonde': 6.375,
#  'room-in-rome': 4.333333333333333,
#  'hotel-chevalier': 7.0,
#  'foxcatcher': 7.266666666666667,
#  'cheaper-by-the-dozen-2': 3.625,
#  'legally-blonde-2-red-white-blonde': 5.666666666666667,
#  'look-whos-talking-now': 3.0,
#  'sound-of-my-voice': 7.2727272727272725,
#  'parenthood': 7.0,
#  'freaky-friday': 6.0,
#  'knowing': 5.368421052631579,
#  'welcome-home-roxy-carmichael': 4.75,
#  'austin-powers-the-spy-who-shagged-me': 6.857142857142857,
#  'my-bloody-valentine-2009': 5.476190476190476,
#  'whats-your-number': 5.181818181818182,
#  'i-am-number-four': 4.666666666666667,
#  'no-strings-attached': 4.6,
#  'snow-white-and-the-huntsman': 5.346153846153846,
#  'riding-in-cars-with-boys': 4.666666666666667,
#  'cashback': 6.714285714285714,
#  'gangster-squad': 5.75,
#  'eagle-vs-shark': 6.666666666666667,
#  'the-descent': 7.947368421052632,
#  'audition': 7.704545454545454,
#  'scary-movie-2': 4.142857142857143,
#  'the-notebook': 6.833333333333333,
#  'willy-wonka-the-chocolate-factory': 8.2,
#  'the-butterfly-effect': 6.444444444444445,
#  'the-way-way-back': 6.730769230769231,
#  'bruce-almighty': 5.4,
#  'the-iron-giant': 8.375,
#  'the-happening': 3.727272727272727,
#  'lawless': 6.956521739130435,
#  'now-you-see-me': 5.7105263157894735,
#  'hugo': 7.419354838709677,
#  'with-every-heartbeat': 6.0,
#  'captain-america-the-first-avenger': 7.127272727272727,
#  'charlies-angels': 5.0588235294117645,
#  'saturday-night-live-40th-anniversary-special': 6.0,
#  'american-sniper': 6.2,
#  'thir13en-ghosts': 5.7272727272727275,
#  'agent-cody-banks': 3.4,
#  'flushed-away': 5.285714285714286,
#  'epic-movie': 1.875,
#  'elephant-2003': 6.0,
#  'hellbound-hellraiser-ii': 6.7272727272727275,
#  'the-pacifier': 4.857142857142857,
#  'nacho-libre': 6.5,
#  'hot-rod': 7.45,
#  'date-night': 5.6,
#  'super-2010': 7.407407407407407,
#  'defendor': 7.0,
#  'the-house-bunny': 4.454545454545454,
#  'bad-words': 5.857142857142857,
#  'the-addams-family': 6.95,
#  'a-tale-of-two-sisters': 7.260869565217392,
#  'employee-of-the-month-2006': 4.571428571428571,
#  'how-to-lose-a-guy-in-10-days': 4.357142857142857,
#  'sunshine-2007': 7.857142857142857,
#  'cursed': 4.416666666666667,
#  'nosferatu': 8.0,
#  'elysium-2013': 6.6571428571428575,
#  'up': 8.243243243243244,
#  'slumdog-millionaire': 7.827586206896552,
#  'the-maze-runner': 6.387096774193548,
#  'romy-and-micheles-high-school-reunion': 6.833333333333333,
#  'winning-london': 5.0,
#  'it-follows': 7.890625,
#  'two-days-one-night': 8.058823529411764,
#  'x-men-days-of-future-past': 7.823529411764706,
#  'ida': 7.470588235294118,
#  'delivery-man': 5.0,
#  'the-princess-diaries-2-royal-engagement': 5.3,
#  'idle-hands': 6.357142857142857,
#  'funny-people': 6.818181818181818,
#  'the-proposal-2009': 5.35,
#  'observe-and-report': 6.4375,
#  'everybodys-fine-2009': 8.0,
#  'idiocracy': 6.722222222222222,
#  'in-time': 5.826086956521739,
#  'another-earth': 7.4375,
#  'this-means-war': 4.181818181818182,
#  'away-we-go': 6.0,
#  'unbreakable': 7.956521739130435,
#  'sky-captain-and-the-world-of-tomorrow': 5.777777777777778,
#  'alice-in-wonderland-1951': 7.0,
#  'harry-potter-and-the-deathly-hallows-part-1': 7.488372093023256,
#  'my-super-ex-girlfriend': 4.363636363636363,
#  'a-trip-to-the-moon': 7.642857142857143,
#  'right-at-your-door': 6.166666666666667,
#  'the-adventures-of-tintin': 6.62962962962963,
#  'brokeback-mountain': 8.521739130434783,
#  'sherlock-holmes-2009': 7.0344827586206895,
#  'sin-city-a-dame-to-kill-for': 5.68,
#  'life-after-beth-2014': 5.153846153846154,
#  'spirited-away': 8.630434782608695,
#  'switching-goals': 3.5,
#  'jurassic-park': 8.76595744680851,
#  'return-to-house-on-haunted-hill': 4.0,
#  'a-very-brady-sequel': 5.0,
#  'look-whos-talking': 6.25,
#  'failure-to-launch': 4.3,
#  'jeepers-creepers': 6.3478260869565215,
#  'jingle-all-the-way': 5.454545454545454,
#  'the-neverending-story': 6.8,
#  'honey-i-shrunk-the-kids': 5.833333333333333,
#  'zack-and-miri-make-a-porno': 5.947368421052632,
#  'surrogates': 5.3076923076923075,
#  'due-date': 5.166666666666667,
#  'tower-heist': 5.4,
#  'the-green-hornet': 5.117647058823529,
#  'for-a-good-time-call': 6.75,
#  'grey-gardens-2009': 8.0,
#  'toy-story': 8.131578947368421,
#  'the-great-train-robbery': 7.125,
#  're-animator': 8.2,
#  'mary-poppins': 6.8125,
#  'american-pie': 6.476190476190476,
#  'lemony-snickets-a-series-of-unfortunate-events': 5.733333333333333,
#  'confessions-of-a-shopaholic': 5.6,
#  'lilo-stitch': 6.75,
#  'hellraiser': 8.117647058823529,
#  'pirates-of-the-caribbean-on-stranger-tides': 5.157894736842105,
#  'eden-lake': 6.625,
#  'safety-not-guaranteed': 6.666666666666667,
#  'the-40-year-old-virgin': 6.7,
#  'ai-artificial-intelligence': 6.7894736842105265,
#  'the-nightmare-before-christmas': 7.5625,
#  'ratatouille': 8.34375,
#  'district-9': 8.058823529411764,
#  'rushmore': 8.028571428571428,
#  'trainspotting': 8.487804878048781,
#  'palo-alto': 5.611111111111111,
#  'edward-scissorhands': 7.689655172413793,
#  'sleepy-hollow': 6.696969696969697,
#  'dont-tell-mom-the-babysitters-dead': 6.8,
#  'push-2009': 5.545454545454546,
#  'nick-and-norahs-infinite-playlist': 6.5,
#  'drop-dead-gorgeous': 6.7272727272727275,
#  'now-and-then': 6.25,
#  ...}

# %%
def test_scores(d, uname, num_neighbors, func):
    target = d["test_matrix"][d["user_to_index"][uname], :].toarray().reshape(1, -1)
    pred = func(d, uname, num_neighbors)
    target = target.flatten().astype('float')
    target[target < 0.5] = 'nan'
    mse = np.nanmean((target - pred) ** 2)
    mae = np.nanmean(abs(target - pred))
    return mse, mae

# %%
import random

NUM_NEIGHBORS = 100
NUM_ITERATIONS = 100

d = get_and_save_or_load_sample()
mse_arr = list()
mae_arr = list()
for i in range(NUM_ITERATIONS):
  uname = random.choice(d["test_users"])
  mse, mae = test_scores(d, uname, NUM_NEIGHBORS, func=predict_scores)
  mse_arr.append(mse)
  mae_arr.append(mae)
print("Average mean squared error for the iterations")
print(np.mean(mse_arr))
print("Average mean absolute error for the iterations")
print(np.mean(mae_arr))
# Out:
# Average mean squared error for the iterations
# 3.000892033533085
# Average mean absolute error for the iterations
# 1.3131210044440709
